# %% [markdown]
# Install Required Libraries

# %%
# !pip install -U transformers datasets peft trl bitsandbytes accelerate evaluate rouge-score nltk absl-py
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (4.53.0)
# Requirement already satisfied: datasets in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: peft in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (0.15.2)
# Requirement already satisfied: trl in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (0.19.0)
# Requirement already satisfied: bitsandbytes in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (0.46.1)
# Requirement already satisfied: accelerate in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (1.8.1)
# Requirement already satisfied: evaluate in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (0.4.4)
# Requirement already satisfied: rouge-score in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: nltk in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: absl-py in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (2.3.0)
# Collecting absl-py
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: filelock in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from datasets) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from datasets) (2.3.0)
# Requirement already satisfied: xxhash in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: psutil in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from peft) (5.9.8)
# Requirement already satisfied: torch>=1.13.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from peft) (2.7.1)
# Requirement already satisfied: six>=1.14.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: setuptools in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (70.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.2)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/anaconda3/envs/genai/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: absl-py
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.3.0
#     Uninstalling absl-py-2.3.0:
#       Successfully uninstalled absl-py-2.3.0
# Successfully installed absl-py-2.3.1

# %% [markdown]
# Login to Hugging Face

# %%
from huggingface_hub import login
login("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")

# %% [markdown]
# Load Dataset and Format for Completion Style

# %%
from datasets import load_dataset

dataset = load_dataset("azizshaw/text_to_json")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'output', 'instruction'],
#         num_rows: 845
#     })
# })

# %%
# See column names
print(dataset["train"].column_names)

# View the first row
print(dataset["train"][0])

# View first few examples (useful for debugging)
for i in range(3):
    print(f"Example {i}:\n", dataset["train"][i], "\n")
# Out:
# ['input', 'output', 'instruction']
# {'input': '1. Send a mobile app notification to customers whose total recharge amount for the last 30 days is equal to 300 and whose total recharge amount for the last 2 weeks is greater than 80.', 'output': "{'featureId': '', 'appName': '', 'username': '', 'password': '', 'reqTxnId': '', 'msgOrigin': '', 'msgDest': '', 'timestamp': '', 'id': '', 'ruletype': '', 'data': {'detail': {'rules': {'id': '0', 'pid': '#', 'childrens': [{'id': '0_0', 'pid': '0', 'type': 'conditions', 'option': 'All', 'childrens': [{'id': '0_0_0', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 1, 'name': 'TOTAL_RECHARGE_REV_LAST_30_DAYS'}, 'operator': '=', 'values': {'value': '300'}}, {'id': '0_0_1', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 3, 'name': 'TOTAL_RECHARGE_REV_LAST_2_WEEKS'}, 'operator': '>', 'values': {'value': '80'}}, {'id': '0_0_2', 'pid': '0_0', 'type': 'action', 'action': {'id': 98, 'name': 'Mobile App Notification'}, 'field': [{'name': 'ActionID', 'value': '0_0_2'}, {'name': 'ActionName', 'value': ''}, {'name': 'ActionCall', 'value': ''}], 'request': {'field': []}}]}]}}}}", 'instruction': 'The task is to generate a json format from a set of keywords.\nI will help you with some details about this format.\nConsider we have a database with us which has telecom details about customers, their puchase, their demographics, their usage of voice,sms.data & so on.\nFor ex. when I say "action_name = push notification, KPI1 = P_AON,OP1 = >, VAL1 = 30, KPI2 = P_DEVICE_TYPE,OP2 = =, VAL2 = phone,option=All" then it means,\n"Send a mobile app notification to customers whose Age on Network (AON) is greater than 30 days & their device type is a phone"\nbased on this we will get the below json:\n{\n\t"featureId": "",\n\t"appName": "",\n\t"username": "",\n\t"password": "",\n\t"reqTxnId": "",\n\t"msgOrigin": "",\n\t"msgDest": "",\n\t"timestamp": "",\n\t"id": "",\n\t"ruletype": "",\n\t"data": {\n\t\t"detail": {\n\t\t\t"rules": {\n\t\t\t\t"id": "0",\n\t\t\t\t"pid": "#",\n\t\t\t\t"childrens": [\n\t\t\t\t\t{\n\t\t\t\t\t\t"id": "0_0",\n\t\t\t\t\t\t"pid": "0",\n\t\t\t\t\t\t"type": "conditions",\n\t\t\t\t\t\t"option": "All",\n\t\t\t\t\t\t"childrens": [\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_0",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 1,\n\t\t\t\t\t\t\t\t\t"name": "P_AON"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": ">",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "30"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_1",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 862,\n\t\t\t\t\t\t\t\t\t"name": "P_DEVICE_TYPE"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": "=",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "PHONE"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_2",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "action",\n\t\t\t\t\t\t\t\t"action": {\n\t\t\t\t\t\t\t\t\t"id": 98,\n\t\t\t\t\t\t\t\t\t"name": "Mobile App Notification"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionID",\n\t\t\t\t\t\t\t\t\t\t"value": "0_0_2"\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionName",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionCall",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t],\n\t\t\t\t\t\t\t\t"request": {\n\t\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t]\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t]\n\t\t\t\t\t}\n\t\t\t\t]\n\t\t\t}\n\t\t}\n\t}\n}\n\n\nIn the above example text, Age on Network refers to "P_AON" profile name & device type refers to "P_DEVICE_TYPE" profile name as seen in json.\nthe specific ids of the above profile names are unique to them,\nyou can ignore while generating them for ...
# Example 0:
#  {'input': '1. Send a mobile app notification to customers whose total recharge amount for the last 30 days is equal to 300 and whose total recharge amount for the last 2 weeks is greater than 80.', 'output': "{'featureId': '', 'appName': '', 'username': '', 'password': '', 'reqTxnId': '', 'msgOrigin': '', 'msgDest': '', 'timestamp': '', 'id': '', 'ruletype': '', 'data': {'detail': {'rules': {'id': '0', 'pid': '#', 'childrens': [{'id': '0_0', 'pid': '0', 'type': 'conditions', 'option': 'All', 'childrens': [{'id': '0_0_0', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 1, 'name': 'TOTAL_RECHARGE_REV_LAST_30_DAYS'}, 'operator': '=', 'values': {'value': '300'}}, {'id': '0_0_1', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 3, 'name': 'TOTAL_RECHARGE_REV_LAST_2_WEEKS'}, 'operator': '>', 'values': {'value': '80'}}, {'id': '0_0_2', 'pid': '0_0', 'type': 'action', 'action': {'id': 98, 'name': 'Mobile App Notification'}, 'field': [{'name': 'ActionID', 'value': '0_0_2'}, {'name': 'ActionName', 'value': ''}, {'name': 'ActionCall', 'value': ''}], 'request': {'field': []}}]}]}}}}", 'instruction': 'The task is to generate a json format from a set of keywords.\nI will help you with some details about this format.\nConsider we have a database with us which has telecom details about customers, their puchase, their demographics, their usage of voice,sms.data & so on.\nFor ex. when I say "action_name = push notification, KPI1 = P_AON,OP1 = >, VAL1 = 30, KPI2 = P_DEVICE_TYPE,OP2 = =, VAL2 = phone,option=All" then it means,\n"Send a mobile app notification to customers whose Age on Network (AON) is greater than 30 days & their device type is a phone"\nbased on this we will get the below json:\n{\n\t"featureId": "",\n\t"appName": "",\n\t"username": "",\n\t"password": "",\n\t"reqTxnId": "",\n\t"msgOrigin": "",\n\t"msgDest": "",\n\t"timestamp": "",\n\t"id": "",\n\t"ruletype": "",\n\t"data": {\n\t\t"detail": {\n\t\t\t"rules": {\n\t\t\t\t"id": "0",\n\t\t\t\t"pid": "#",\n\t\t\t\t"childrens": [\n\t\t\t\t\t{\n\t\t\t\t\t\t"id": "0_0",\n\t\t\t\t\t\t"pid": "0",\n\t\t\t\t\t\t"type": "conditions",\n\t\t\t\t\t\t"option": "All",\n\t\t\t\t\t\t"childrens": [\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_0",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 1,\n\t\t\t\t\t\t\t\t\t"name": "P_AON"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": ">",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "30"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_1",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 862,\n\t\t\t\t\t\t\t\t\t"name": "P_DEVICE_TYPE"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": "=",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "PHONE"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_2",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "action",\n\t\t\t\t\t\t\t\t"action": {\n\t\t\t\t\t\t\t\t\t"id": 98,\n\t\t\t\t\t\t\t\t\t"name": "Mobile App Notification"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionID",\n\t\t\t\t\t\t\t\t\t\t"value": "0_0_2"\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionName",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionCall",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t],\n\t\t\t\t\t\t\t\t"request": {\n\t\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t]\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t]\n\t\t\t\t\t}\n\t\t\t\t]\n\t\t\t}\n\t\t}\n\t}\n}\n\n\nIn the above example text, Age on Network refers to "P_AON" profile name & device type refers to "P_DEVICE_TYPE" profile name as seen in json.\nthe specific ids of the above profile names are unique to them,\nyou can ignore while generating them fo ...
#
# Example 1:
#  {'input': '2. Customers who have a total recharge amount of 300 for the last 30 days and a total recharge amount greater than 80 for the last 2 weeks should receive a mobile app notification.', 'output': "{'featureId': '', 'appName': '', 'username': '', 'password': '', 'reqTxnId': '', 'msgOrigin': '', 'msgDest': '', 'timestamp': '', 'id': '', 'ruletype': '', 'data': {'detail': {'rules': {'id': '0', 'pid': '#', 'childrens': [{'id': '0_0', 'pid': '0', 'type': 'conditions', 'option': 'All', 'childrens': [{'id': '0_0_0', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 1, 'name': 'TOTAL_RECHARGE_REV_LAST_30_DAYS'}, 'operator': '=', 'values': {'value': '300'}}, {'id': '0_0_1', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 3, 'name': 'TOTAL_RECHARGE_REV_LAST_2_WEEKS'}, 'operator': '>', 'values': {'value': '80'}}, {'id': '0_0_2', 'pid': '0_0', 'type': 'action', 'action': {'id': 98, 'name': 'Mobile App Notification'}, 'field': [{'name': 'ActionID', 'value': '0_0_2'}, {'name': 'ActionName', 'value': ''}, {'name': 'ActionCall', 'value': ''}], 'request': {'field': []}}]}]}}}}", 'instruction': 'The task is to generate a json format from a set of keywords.\nI will help you with some details about this format.\nConsider we have a database with us which has telecom details about customers, their puchase, their demographics, their usage of voice,sms.data & so on.\nFor ex. when I say "action_name = push notification, KPI1 = P_AON,OP1 = >, VAL1 = 30, KPI2 = P_DEVICE_TYPE,OP2 = =, VAL2 = phone,option=All" then it means,\n"Send a mobile app notification to customers whose Age on Network (AON) is greater than 30 days & their device type is a phone"\nbased on this we will get the below json:\n{\n\t"featureId": "",\n\t"appName": "",\n\t"username": "",\n\t"password": "",\n\t"reqTxnId": "",\n\t"msgOrigin": "",\n\t"msgDest": "",\n\t"timestamp": "",\n\t"id": "",\n\t"ruletype": "",\n\t"data": {\n\t\t"detail": {\n\t\t\t"rules": {\n\t\t\t\t"id": "0",\n\t\t\t\t"pid": "#",\n\t\t\t\t"childrens": [\n\t\t\t\t\t{\n\t\t\t\t\t\t"id": "0_0",\n\t\t\t\t\t\t"pid": "0",\n\t\t\t\t\t\t"type": "conditions",\n\t\t\t\t\t\t"option": "All",\n\t\t\t\t\t\t"childrens": [\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_0",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 1,\n\t\t\t\t\t\t\t\t\t"name": "P_AON"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": ">",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "30"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_1",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 862,\n\t\t\t\t\t\t\t\t\t"name": "P_DEVICE_TYPE"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": "=",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "PHONE"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_2",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "action",\n\t\t\t\t\t\t\t\t"action": {\n\t\t\t\t\t\t\t\t\t"id": 98,\n\t\t\t\t\t\t\t\t\t"name": "Mobile App Notification"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionID",\n\t\t\t\t\t\t\t\t\t\t"value": "0_0_2"\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionName",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionCall",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t],\n\t\t\t\t\t\t\t\t"request": {\n\t\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t]\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t]\n\t\t\t\t\t}\n\t\t\t\t]\n\t\t\t}\n\t\t}\n\t}\n}\n\n\nIn the above example text, Age on Network refers to "P_AON" profile name & device type refers to "P_DEVICE_TYPE" profile name as seen in json.\nthe specific ids of the above profile names are unique to them,\nyou can ignore while generating them for no ...
#
# Example 2:
#  {'input': '3. If the total recharge amount for the last 30 days is equal to 300 and the total recharge amount for the last 2 weeks is greater than 80, send a mobile app notification to the customers.', 'output': "{'featureId': '', 'appName': '', 'username': '', 'password': '', 'reqTxnId': '', 'msgOrigin': '', 'msgDest': '', 'timestamp': '', 'id': '', 'ruletype': '', 'data': {'detail': {'rules': {'id': '0', 'pid': '#', 'childrens': [{'id': '0_0', 'pid': '0', 'type': 'conditions', 'option': 'All', 'childrens': [{'id': '0_0_0', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 1, 'name': 'TOTAL_RECHARGE_REV_LAST_30_DAYS'}, 'operator': '=', 'values': {'value': '300'}}, {'id': '0_0_1', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 3, 'name': 'TOTAL_RECHARGE_REV_LAST_2_WEEKS'}, 'operator': '>', 'values': {'value': '80'}}, {'id': '0_0_2', 'pid': '0_0', 'type': 'action', 'action': {'id': 98, 'name': 'Mobile App Notification'}, 'field': [{'name': 'ActionID', 'value': '0_0_2'}, {'name': 'ActionName', 'value': ''}, {'name': 'ActionCall', 'value': ''}], 'request': {'field': []}}]}]}}}}", 'instruction': 'The task is to generate a json format from a set of keywords.\nI will help you with some details about this format.\nConsider we have a database with us which has telecom details about customers, their puchase, their demographics, their usage of voice,sms.data & so on.\nFor ex. when I say "action_name = push notification, KPI1 = P_AON,OP1 = >, VAL1 = 30, KPI2 = P_DEVICE_TYPE,OP2 = =, VAL2 = phone,option=All" then it means,\n"Send a mobile app notification to customers whose Age on Network (AON) is greater than 30 days & their device type is a phone"\nbased on this we will get the below json:\n{\n\t"featureId": "",\n\t"appName": "",\n\t"username": "",\n\t"password": "",\n\t"reqTxnId": "",\n\t"msgOrigin": "",\n\t"msgDest": "",\n\t"timestamp": "",\n\t"id": "",\n\t"ruletype": "",\n\t"data": {\n\t\t"detail": {\n\t\t\t"rules": {\n\t\t\t\t"id": "0",\n\t\t\t\t"pid": "#",\n\t\t\t\t"childrens": [\n\t\t\t\t\t{\n\t\t\t\t\t\t"id": "0_0",\n\t\t\t\t\t\t"pid": "0",\n\t\t\t\t\t\t"type": "conditions",\n\t\t\t\t\t\t"option": "All",\n\t\t\t\t\t\t"childrens": [\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_0",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 1,\n\t\t\t\t\t\t\t\t\t"name": "P_AON"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": ">",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "30"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_1",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "condition",\n\t\t\t\t\t\t\t\t"profile": {\n\t\t\t\t\t\t\t\t\t"id": 862,\n\t\t\t\t\t\t\t\t\t"name": "P_DEVICE_TYPE"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"operator": "=",\n\t\t\t\t\t\t\t\t"values": {\n\t\t\t\t\t\t\t\t\t"value": "PHONE"\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t"id": "0_0_2",\n\t\t\t\t\t\t\t\t"pid": "0_0",\n\t\t\t\t\t\t\t\t"type": "action",\n\t\t\t\t\t\t\t\t"action": {\n\t\t\t\t\t\t\t\t\t"id": 98,\n\t\t\t\t\t\t\t\t\t"name": "Mobile App Notification"\n\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionID",\n\t\t\t\t\t\t\t\t\t\t"value": "0_0_2"\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionName",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t{\n\t\t\t\t\t\t\t\t\t\t"name": "ActionCall",\n\t\t\t\t\t\t\t\t\t\t"value": ""\n\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t],\n\t\t\t\t\t\t\t\t"request": {\n\t\t\t\t\t\t\t\t\t"field": [\n\t\t\t\t\t\t\t\t\t]\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t]\n\t\t\t\t\t}\n\t\t\t\t]\n\t\t\t}\n\t\t}\n\t}\n}\n\n\nIn the above example text, Age on Network refers to "P_AON" profile name & device type refers to "P_DEVICE_TYPE" profile name as seen in json.\nthe specific ids of the above profile names are unique to them,\nyou can ignore while generating the ...

# %%
"""def format_example(example):
    return {
        "text": f"Convert the following text into JSON:\n\n{example['instruction']}\n\nJSON:\n{example['output']}"
    }

train_data = dataset["train"].map(format_example)"""

# %%
def format_example(example):
    return {
        "text": f"Convert the following text into JSON: {example['instruction']}\n\nInput: {example['input']}\n\nJSON:\n{example['output']}"
    }
train_data = dataset["train"].map(format_example)
# Out:
# Map: 100%|██████████| 845/845 [00:00<00:00, 9699.13 examples/s]

# %% [markdown]
# Load Meta-Llama 3.1–8B Base Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import prepare_model_for_kbit_training
import torch

model_name = "meta-llama/Meta-Llama-3.1-8B"

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=torch.bfloat16
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s]

# %%
model = prepare_model_for_kbit_training(model)

# %% [markdown]
# Apply LoRA (QLoRA)

# %%
from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM,
)

model = get_peft_model(model, lora_config)

# %% [markdown]
# Load Tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# Fine-Tune with SFTTrainer

# %%
from trl import SFTTrainer, SFTConfig

sft_config = SFTConfig(
    output_dir="./llama3-8b-base-json",
    per_device_train_batch_size=1,
    gradient_checkpointing=True,
    bf16=True,
    logging_steps=10,
    num_train_epochs=3,
    save_strategy="epoch"
)

# %%
def formatting_func(example):
    return example["text"]

trainer = SFTTrainer(
    model=model,
    
    args=sft_config,
    train_dataset=train_data,
    formatting_func=formatting_func,
    
)
# Out:
# Applying formatting function to train dataset: 100%|██████████| 845/845 [00:00<00:00, 10733.49 examples/s]
# Adding EOS to train dataset: 100%|██████████| 845/845 [00:00<00:00, 12061.87 examples/s]
# Tokenizing train dataset: 100%|██████████| 845/845 [00:02<00:00, 317.85 examples/s]
# Truncating train dataset: 100%|██████████| 845/845 [00:00<00:00, 23842.33 examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2535' max='2535' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2535/2535 1:13:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.677600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.650400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.607800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.553500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.486200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.405200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.305600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.180400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.042300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.916100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.779900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.616300</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.434800</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.284000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.194600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.157100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.129100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.105000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.079800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.058700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.041300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.029300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.022900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.019400</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.017800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.017000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.016400</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.015100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.014300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.013300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.011600</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.010800</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.010400</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.009800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.009600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.009500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.009400</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>1
# TrainOutput(global_step=2535, training_loss=0.07425699958934116, metrics={'train_runtime': 4426.7475, 'train_samples_per_second': 0.573, 'train_steps_per_second': 0.573, 'total_flos': 1.1694257970610176e+17, 'train_loss': 0.07425699958934116})

# %%
finetuned_model = trainer.model

# %% [markdown]
#  Evaluate (ROUGE + JSON Validity)

# %%
from evaluate import load
from tqdm import tqdm
import json

rouge = load("rouge")

def evaluate_model(model, tokenizer, data, check_json=False):
    predictions, references = [], []
    valid_json = 0
    model.eval()

    for example in tqdm(data, desc="Evaluating"):
        prompt = f"Convert the following text into JSON:\n\n{example['instruction']}\n\nJSON:"
        input_ids = tokenizer(prompt, return_tensors="pt", truncation=True).input_ids.to(model.device)

        with torch.no_grad():
            output_ids = model.generate(input_ids, max_new_tokens=256)
        output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
        generated = output.split("JSON:")[-1].strip()

        predictions.append(generated)
        references.append(example["output"])

        if check_json:
            try:
                json.loads(generated)
                valid_json += 1
            except:
                pass

    score = rouge.compute(predictions=predictions, references=references)
    if check_json:
        score["valid_json_percent"] = round(100 * valid_json / len(predictions), 2)

    return score

eval_data = dataset["test"] if "test" in dataset else dataset["train"].select(range(10))
results = evaluate_model(finetuned_model, tokenizer, eval_data, check_json=True)

print("📊 Fine-tuned Base Model Results:", results)
# Out:
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  10%|█         | 1/10 [00:14<02:10, 14.52s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  20%|██        | 2/10 [00:31<02:07, 15.90s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  30%|███       | 3/10 [00:48<01:54, 16.34s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  40%|████      | 4/10 [01:05<01:39, 16.55s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  50%|█████     | 5/10 [01:22<01:23, 16.70s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  60%|██████    | 6/10 [01:39<01:07, 16.83s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  70%|███████   | 7/10 [01:56<00:50, 16.92s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  80%|████████  | 8/10 [02:13<00:33, 16.98s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  90%|█████████ | 9/10 [02:30<00:17, 17.01s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating: 100%|██████████| 10/10 [02:45<00:00, 16.55s/it]
# 📊 Fine-tuned Base Model Results: {'rouge1': np.float64(0.5408918967613718), 'rouge2': np.float64(0.396147617526993), 'rougeL': np.float64(0.49322191130966864), 'rougeLsum': np.float64(0.31012134795580737), 'valid_json_percent': 0.0}

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

base_model_name = "meta-llama/Meta-Llama-3.1-8B"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True, 
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    quantization_config=bnb_config
)

base_tokenizer = AutoTokenizer.from_pretrained(base_model_name)
base_tokenizer.pad_token = base_tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:13<00:00,  3.40s/it]

# %%
# Select a small subset to test (e.g., 10 examples)
eval_data = dataset["test"] if "test" in dataset else dataset["train"].select(range(10))

# Base model (Llama 3.1 8B)
results_base = evaluate_model(base_model, base_tokenizer, eval_data, check_json=True)

# Fine-tuned model
results_finetuned = evaluate_model(finetuned_model, tokenizer, eval_data, check_json=True)

# Display results
print("🔹 Base Model (Llama-3.1-8B):", results_base)
print("✅ Fine-tuned Model:", results_finetuned)
# Out:
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  10%|█         | 1/10 [00:13<02:01, 13.45s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  20%|██        | 2/10 [00:27<01:48, 13.58s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  30%|███       | 3/10 [00:40<01:35, 13.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  40%|████      | 4/10 [00:54<01:22, 13.68s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  50%|█████     | 5/10 [01:08<01:08, 13.69s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  60%|██████    | 6/10 [01:21<00:54, 13.61s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  70%|███████   | 7/10 [01:35<00:40, 13.55s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  80%|████████  | 8/10 [01:48<00:26, 13.49s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  90%|█████████ | 9/10 [02:01<00:13, 13.46s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating: 100%|██████████| 10/10 [02:15<00:00, 13.53s/it]
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  10%|█         | 1/10 [00:20<03:02, 20.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  20%|██        | 2/10 [00:40<02:41, 20.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  30%|███       | 3/10 [01:00<02:20, 20.11s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  40%|████      | 4/10 [01:15<01:49, 18.32s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  50%|█████     | 5/10 [01:36<01:34, 18.95s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  60%|██████    | 6/10 [01:56<01:17, 19.34s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  70%|███████   | 7/10 [02:16<00:58, 19.61s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  80%|████████  | 8/10 [02:32<00:36, 18.39s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating:  90%|█████████ | 9/10 [02:47<00:17, 17.55s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating: 100%|██████████| 10/10 [03:03<00:00, 18.36s/it]
# 🔹 Base Model (Llama-3.1-8B): {'rouge1': np.float64(0.7089763678309513), 'rouge2': np.float64(0.6889421338155516), 'rougeL': np.float64(0.7039641870401184), 'rougeLsum': np.float64(0.4733931682193441), 'valid_json_percent': 0.0}
# ✅ Fine-tuned Model: {'rouge1': np.float64(0.616991695233368), 'rouge2': np.float64(0.5697565786913337), 'rougeL': np.float64(0.611339706236674), 'rougeLsum': np.float64(0.37832270264491885), 'valid_json_percent': 0.0}

# %%
import pandas as pd
pd.DataFrame([results_base, results_finetuned], index=["Base", "Fine-tuned"])
# Out:
#               rouge1    rouge2    rougeL  rougeLsum  valid_json_percent
# Base        0.708976  0.688942  0.703964   0.473393                 0.0
# Fine-tuned  0.616992  0.569757  0.611340   0.378323                 0.0

# %% [markdown]
# Step-by-Step: Compare Model Outputs1. Define the prompt and generate output from both models

# %%
def compare_models(example, base_model, base_tokenizer, finetuned_model, finetuned_tokenizer):
    instruction = example["instruction"]
    reference_output = example["output"]

    prompt = f"Convert the following text into JSON:\n\n{instruction}\n\nJSON:"

    # Tokenize and move to device
    base_inputs = base_tokenizer(prompt, return_tensors="pt").to(base_model.device)
    finetune_inputs = finetuned_tokenizer(prompt, return_tensors="pt").to(finetuned_model.device)

    # Generate outputs
    with torch.no_grad():
        base_output_ids = base_model.generate(base_inputs["input_ids"], max_new_tokens=256)
        finetune_output_ids = finetuned_model.generate(finetune_inputs["input_ids"], max_new_tokens=256)

    base_output = base_tokenizer.decode(base_output_ids[0], skip_special_tokens=True).split("JSON:")[-1].strip()
    finetuned_output = finetuned_tokenizer.decode(finetune_output_ids[0], skip_special_tokens=True).split("JSON:")[-1].strip()

    print("🔹 Prompt:\n", prompt)
    print(" Ground Truth:\n", reference_output)
    print(" Base Model Output:\n", base_output)
    print(" Fine-tuned Model Output:\n", finetuned_output)

# %% [markdown]
#  Use it on a sample from the dataset

# %%
sample = dataset["train"][0]  # You can change index here
compare_models(sample, base_model, base_tokenizer, finetuned_model, tokenizer)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 🔹 Prompt:
#  Convert the following text into JSON:
#
# The task is to generate a json format from a set of keywords.
# I will help you with some details about this format.
# Consider we have a database with us which has telecom details about customers, their puchase, their demographics, their usage of voice,sms.data & so on.
# For ex. when I say "action_name = push notification, KPI1 = P_AON,OP1 = >, VAL1 = 30, KPI2 = P_DEVICE_TYPE,OP2 = =, VAL2 = phone,option=All" then it means,
# "Send a mobile app notification to customers whose Age on Network (AON) is greater than 30 days & their device type is a phone"
# based on this we will get the below json:
# {
# 	"featureId": "",
# 	"appName": "",
# 	"username": "",
# 	"password": "",
# 	"reqTxnId": "",
# 	"msgOrigin": "",
# 	"msgDest": "",
# 	"timestamp": "",
# 	"id": "",
# 	"ruletype": "",
# 	"data": {
# 		"detail": {
# 			"rules": {
# 				"id": "0",
# 				"pid": "#",
# 				"childrens": [
# 					{
# 						"id": "0_0",
# 						"pid": "0",
# 						"type": "conditions",
# 						"option": "All",
# 						"childrens": [
# 							{
# 								"id": "0_0_0",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 1,
# 									"name": "P_AON"
# 								},
# 								"operator": ">",
# 								"values": {
# 									"value": "30"
# 								}
# 							},
# 							{
# 								"id": "0_0_1",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 862,
# 									"name": "P_DEVICE_TYPE"
# 								},
# 								"operator": "=",
# 								"values": {
# 									"value": "PHONE"
# 								}
# 							},
# 							{
# 								"id": "0_0_2",
# 								"pid": "0_0",
# 								"type": "action",
# 								"action": {
# 									"id": 98,
# 									"name": "Mobile App Notification"
# 								},
# 								"field": [
# 									{
# 										"name": "ActionID",
# 										"value": "0_0_2"
# 									},
# 									{
# 										"name": "ActionName",
# 										"value": ""
# 									},
# 									{
# 										"name": "ActionCall",
# 										"value": ""
# 									}
# 								],
# 								"request": {
# 									"field": [
# 									]
# 								}
# 							}
# 						]
# 					}
# 				]
# 			}
# 		}
# 	}
# }
#
#
# In the above example text, Age on Network refers to "P_AON" profile name & device type refers to "P_DEVICE_TYPE" profile name as seen in json.
# the specific ids of the above profile names are unique to them,
# you can ignore while generating them for now, later on I will tell you which idnumber to fill.
# This is an 'AND' condition as in if the two conditions fulfill then only send a mobile notification, hence in the json "option":"All" is given to say that if "all conditons specify then only do this action".
# if it was "Any" then it would mean "if any condition is fulfilled then perform action"
#
# Here are few other details about the json format:
# (A) Data and Detail Section
# 1. childrens: Array of child objects. Each object represents a condition or an action.
#  2. type: String. Specifies if it's a 'condition' or 'action' or a logical operator like 'any' or 'and'.
# If type is 'any' or 'and', it contains a conditions array with condition objects.
# If type is 'condition' or 'action', it follows the respective structures below.
# Condition Structure
# id
# pid
# profile: Object containing details of the condition.
# name: String. The name of the condition.
# id:
# operator: String. The operation applied in the condition (e.g., '=', '<>').
# values: String. The values to check against in the condition.
#
# Here's a list of profile names available in our database & the possible values(not exhaustive):
# a. TOTAL_RECHARGE_REV_LAST_30_DAYS - 100,200,300,500
# b. TOTAL_RECHARGE_REV_LAST_MONTH - 100,200,300,500
# c. TOTAL_RECHARGE_REV_LAST_2_WEEKs - 50,60,70,80
# d. TOTAL_RECHARGE_REV_LAST_WEEK - 25,30,35,40
# if any query related to recharge amount comes use the above format.
# apart from that:
# a. P_AON (AON - age on network)  - 30,60,90,120
# b. P_InactiveDays - 30,60,90,120
# c. BE_BUNDLE_EXPIRY_DATE - today, tomorrow, last_week,last_month,
# d. P_DEVICE_TYPE - mobile phone, tablet, broadband, telephone
#
# similarly, below are some of the action names:
# a. Mobile App Notification
# b. Send SMS
# c. EMAIL
# d. Push Notification
#
# Your objective will be to generate the same JSON format,
# I will give you the following details - action_name,option,KPI1,KPI2,KPI3 & so-on, operator & value respectively.
# try to follow the above profile names and action names only, make your own variations if the name does not exist. The id no. you can choose your own.
# action_name = Mobile App Notification, KPI1 = TOTAL_RECHARGE_REV_LAST_30_DAYS, OP1 = =, VAL1 = 300, KPI2 = TOTAL_RECHARGE_REV_LAST_2_WEEKS, OP2 = >, VAL2 = 80, option = All
#
# JSON:
# ✅ Ground Truth:
#  {'featureId': '', 'appName': '', 'username': '', 'password': '', 'reqTxnId': '', 'msgOrigin': '', 'msgDest': '', 'timestamp': '', 'id': '', 'ruletype': '', 'data': {'detail': {'rules': {'id': '0', 'pid': '#', 'childrens': [{'id': '0_0', 'pid': '0', 'type': 'conditions', 'option': 'All', 'childrens': [{'id': '0_0_0', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 1, 'name': 'TOTAL_RECHARGE_REV_LAST_30_DAYS'}, 'operator': '=', 'values': {'value': '300'}}, {'id': '0_0_1', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 3, 'name': 'TOTAL_RECHARGE_REV_LAST_2_WEEKS'}, 'operator': '>', 'values': {'value': '80'}}, {'id': '0_0_2', 'pid': '0_0', 'type': 'action', 'action': {'id': 98, 'name': 'Mobile App Notification'}, 'field': [{'name': 'ActionID', 'value': '0_0_2'}, {'name': 'ActionName', 'value': ''}, {'name': 'ActionCall', 'value': ''}], 'request': {'field': []}}]}]}}}}
# 🧠 Base Model Output:
#  {
# 	"featureId": "",
# 	"appName": "",
# 	"username": "",
# 	"password": "",
# 	"reqTxnId": "",
# 	"msgOrigin": "",
# 	"msgDest": "",
# 	"timestamp": "",
# 	"id": "",
# 	"ruletype": "",
# 	"data": {
# 		"detail": {
# 			"rules": {
# 				"id": "0",
# 				"pid": "#",
# 				"childrens": [
# 					{
# 						"id": "0_0",
# 						"pid": "0",
# 						"type": "conditions",
# 						"option": "All",
# 						"childrens": [
# 							{
# 								"id": "0_0_0",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 1,
# 									"name": "TOTAL_RECHARGE_REV_LAST_30_DAYS"
# 								},
# 								"operator": "=",
# 								"values": {
# 									"value": "300"
# 								}
# 							},
# 							{
# 								"id": "0_0_1",
# 								"pid": "0_0",
# 								"type": "condition",
# 🎯 Fine-tuned Model Output:
#  {
# 	"detail": {
# 		"rules": {
# 			"id": "0",
# 			"pid": "#",
# 			"childrens": [
# 				{
# 					"id": "0_0",
# 					"pid": "0",
# 					"type": "condition",
# 					"profile": {
# 						"name": ""
# 					},
# 					"operator": "",
# 					"values": ""
# 				},
# 				{
# 					"id": "0_1",
# 					"pid": "0",
# 					"type": "condition",
# 					"profile": {
# 						"name": ""

# %%
def compare_models(example, base_model, base_tokenizer, finetuned_model, finetuned_tokenizer):
    instruction = example["instruction"]
    reference_output = example["output"]

    prompt = f"Convert the following text into JSON:\n\n{instruction}\n\nJSON:"
    print("\n🔹 Prompt:\n", prompt)
    print("\n Ground Truth:\n", reference_output)

    # Base Model
    base_inputs = base_tokenizer(prompt, return_tensors="pt").to(base_model.device)
    with torch.no_grad():
        base_output_ids = base_model.generate(base_inputs["input_ids"], max_new_tokens=512)
    base_output = base_tokenizer.decode(base_output_ids[0], skip_special_tokens=True).split("JSON:")[-1].strip()
    print("\n Base Model Output:\n", base_output)

    # Fine-tuned Model
    finetune_inputs = finetuned_tokenizer(prompt, return_tensors="pt").to(finetuned_model.device)
    with torch.no_grad():
        finetune_output_ids = finetuned_model.generate(finetune_inputs["input_ids"], max_new_tokens=512)
    finetuned_output = finetuned_tokenizer.decode(finetune_output_ids[0], skip_special_tokens=True).split("JSON:")[-1].strip()
    print("\n Fine-tuned Model Output:\n", finetuned_output)

# %%
compare_models(dataset["train"][0], base_model, base_tokenizer, finetuned_model, tokenizer)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 🔹 Prompt:
#  Convert the following text into JSON:
#
# The task is to generate a json format from a set of keywords.
# I will help you with some details about this format.
# Consider we have a database with us which has telecom details about customers, their puchase, their demographics, their usage of voice,sms.data & so on.
# For ex. when I say "action_name = push notification, KPI1 = P_AON,OP1 = >, VAL1 = 30, KPI2 = P_DEVICE_TYPE,OP2 = =, VAL2 = phone,option=All" then it means,
# "Send a mobile app notification to customers whose Age on Network (AON) is greater than 30 days & their device type is a phone"
# based on this we will get the below json:
# {
# 	"featureId": "",
# 	"appName": "",
# 	"username": "",
# 	"password": "",
# 	"reqTxnId": "",
# 	"msgOrigin": "",
# 	"msgDest": "",
# 	"timestamp": "",
# 	"id": "",
# 	"ruletype": "",
# 	"data": {
# 		"detail": {
# 			"rules": {
# 				"id": "0",
# 				"pid": "#",
# 				"childrens": [
# 					{
# 						"id": "0_0",
# 						"pid": "0",
# 						"type": "conditions",
# 						"option": "All",
# 						"childrens": [
# 							{
# 								"id": "0_0_0",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 1,
# 									"name": "P_AON"
# 								},
# 								"operator": ">",
# 								"values": {
# 									"value": "30"
# 								}
# 							},
# 							{
# 								"id": "0_0_1",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 862,
# 									"name": "P_DEVICE_TYPE"
# 								},
# 								"operator": "=",
# 								"values": {
# 									"value": "PHONE"
# 								}
# 							},
# 							{
# 								"id": "0_0_2",
# 								"pid": "0_0",
# 								"type": "action",
# 								"action": {
# 									"id": 98,
# 									"name": "Mobile App Notification"
# 								},
# 								"field": [
# 									{
# 										"name": "ActionID",
# 										"value": "0_0_2"
# 									},
# 									{
# 										"name": "ActionName",
# 										"value": ""
# 									},
# 									{
# 										"name": "ActionCall",
# 										"value": ""
# 									}
# 								],
# 								"request": {
# 									"field": [
# 									]
# 								}
# 							}
# 						]
# 					}
# 				]
# 			}
# 		}
# 	}
# }
#
#
# In the above example text, Age on Network refers to "P_AON" profile name & device type refers to "P_DEVICE_TYPE" profile name as seen in json.
# the specific ids of the above profile names are unique to them,
# you can ignore while generating them for now, later on I will tell you which idnumber to fill.
# This is an 'AND' condition as in if the two conditions fulfill then only send a mobile notification, hence in the json "option":"All" is given to say that if "all conditons specify then only do this action".
# if it was "Any" then it would mean "if any condition is fulfilled then perform action"
#
# Here are few other details about the json format:
# (A) Data and Detail Section
# 1. childrens: Array of child objects. Each object represents a condition or an action.
#  2. type: String. Specifies if it's a 'condition' or 'action' or a logical operator like 'any' or 'and'.
# If type is 'any' or 'and', it contains a conditions array with condition objects.
# If type is 'condition' or 'action', it follows the respective structures below.
# Condition Structure
# id
# pid
# profile: Object containing details of the condition.
# name: String. The name of the condition.
# id:
# operator: String. The operation applied in the condition (e.g., '=', '<>').
# values: String. The values to check against in the condition.
#
# Here's a list of profile names available in our database & the possible values(not exhaustive):
# a. TOTAL_RECHARGE_REV_LAST_30_DAYS - 100,200,300,500
# b. TOTAL_RECHARGE_REV_LAST_MONTH - 100,200,300,500
# c. TOTAL_RECHARGE_REV_LAST_2_WEEKs - 50,60,70,80
# d. TOTAL_RECHARGE_REV_LAST_WEEK - 25,30,35,40
# if any query related to recharge amount comes use the above format.
# apart from that:
# a. P_AON (AON - age on network)  - 30,60,90,120
# b. P_InactiveDays - 30,60,90,120
# c. BE_BUNDLE_EXPIRY_DATE - today, tomorrow, last_week,last_month,
# d. P_DEVICE_TYPE - mobile phone, tablet, broadband, telephone
#
# similarly, below are some of the action names:
# a. Mobile App Notification
# b. Send SMS
# c. EMAIL
# d. Push Notification
#
# Your objective will be to generate the same JSON format,
# I will give you the following details - action_name,option,KPI1,KPI2,KPI3 & so-on, operator & value respectively.
# try to follow the above profile names and action names only, make your own variations if the name does not exist. The id no. you can choose your own.
# action_name = Mobile App Notification, KPI1 = TOTAL_RECHARGE_REV_LAST_30_DAYS, OP1 = =, VAL1 = 300, KPI2 = TOTAL_RECHARGE_REV_LAST_2_WEEKS, OP2 = >, VAL2 = 80, option = All
#
# JSON:
#
#  Ground Truth:
#  {'featureId': '', 'appName': '', 'username': '', 'password': '', 'reqTxnId': '', 'msgOrigin': '', 'msgDest': '', 'timestamp': '', 'id': '', 'ruletype': '', 'data': {'detail': {'rules': {'id': '0', 'pid': '#', 'childrens': [{'id': '0_0', 'pid': '0', 'type': 'conditions', 'option': 'All', 'childrens': [{'id': '0_0_0', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 1, 'name': 'TOTAL_RECHARGE_REV_LAST_30_DAYS'}, 'operator': '=', 'values': {'value': '300'}}, {'id': '0_0_1', 'pid': '0_0', 'type': 'condition', 'profile': {'id': 3, 'name': 'TOTAL_RECHARGE_REV_LAST_2_WEEKS'}, 'operator': '>', 'values': {'value': '80'}}, {'id': '0_0_2', 'pid': '0_0', 'type': 'action', 'action': {'id': 98, 'name': 'Mobile App Notification'}, 'field': [{'name': 'ActionID', 'value': '0_0_2'}, {'name': 'ActionName', 'value': ''}, {'name': 'ActionCall', 'value': ''}], 'request': {'field': []}}]}]}}}}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  Base Model Output:
#  {
# 	"featureId": "",
# 	"appName": "",
# 	"username": "",
# 	"password": "",
# 	"reqTxnId": "",
# 	"msgOrigin": "",
# 	"msgDest": "",
# 	"timestamp": "",
# 	"id": "",
# 	"ruletype": "",
# 	"data": {
# 		"detail": {
# 			"rules": {
# 				"id": "0",
# 				"pid": "#",
# 				"childrens": [
# 					{
# 						"id": "0_0",
# 						"pid": "0",
# 						"type": "conditions",
# 						"option": "All",
# 						"childrens": [
# 							{
# 								"id": "0_0_0",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 1,
# 									"name": "TOTAL_RECHARGE_REV_LAST_30_DAYS"
# 								},
# 								"operator": "=",
# 								"values": {
# 									"value": "300"
# 								}
# 							},
# 							{
# 								"id": "0_0_1",
# 								"pid": "0_0",
# 								"type": "condition",
# 								"profile": {
# 									"id": 2,
# 									"name": "TOTAL_RECHARGE_REV_LAST_2_WEEKS"
# 								},
# 								"operator": ">",
# 								"values": {
# 									"value": "80"
# 								}
# 							},
# 							{
# 								"id": "0_0_2",
# 								"pid": "0_0",
# 								"type": "action",
# 								"action": {
# 									"id": 98,
# 									"name": "Mobile App Notification"
# 								},
# 								"field": [
# 									{
# 										"name": "ActionID",
# 										"value": "0_0_2"
# 									},
# 									{
# 										"name": "ActionName",
# 										"value": ""
# 									},
# 									{
# 										"name": "ActionCall",
# 										"value": ""
# 									}
# 								],
# 								"request": {
# 									"field": [
# 									]
# 								}
# 							}
# 						]
# 					}
# 				]
# 			}
# 		}
# 	}
# }
#
# Note that the above JSON format is an example, you can choose to use your own action name & KPI name as long as they are in the format as shown
#
#  Fine-tuned Model Output:
#  {
# 	"detail": {
# 		"rules": {
# 			"id": "0",
# 			"pid": "#",
# 			"childrens": [
# 				{
# 					"id": "0_0",
# 					"pid": "0",
# 					"type": "conditions",
# 					"option": "All",
# 					"childrens": [
# 						{
# 							"id": "0_0_0",
# 							"pid": "0_0",
# 							"type": "condition",
# 							"profile": {
# 								"name": ""
# 							},
# 							"operator": ""
# 						},
# 						{
# 							"id": "0_0_1",
# 							"pid": "0_0",
# 							"type": "condition",
# 							"profile": {
# 								"name": ""
# 							},
# 							"operator": ""
# 						},
# 						{
# 							"id": "0_0_2",
# 							"pid": "0_0",
# 							"type": "action",
# 							"action": {
# 								"name": ""
# 							}
# 						}
# 					]
# 				}
# 			]
# 		}
# 	}
# }
#
#
# Here are few other details about the json format:
# (A) Data and Detail Section
# 1. childrens: Array of child objects. Each object represents a condition or an action.
#  2. type: String. Specifies if it's a 'condition' or 'action' or a logical operator like 'any' or 'and'.
# If type is 'any' or 'and', it contains a conditions array with condition objects.
# If type is 'condition' or 'action', it follows the respective structures below.
# Condition Structure
# id
# pid
# profile: Object containing details of the condition.
# name: String. The name of the condition.
# id:
# operator: String. The operation applied in the condition (e.g., '=', '<>').
# values: String. The values to check against in the condition.
#
# Here's a list of profile names available in our database & the possible values(not exhaustive):
# a. TOTAL_RECHARGE_REV_LAST_30_DAYS - 100,200,300,500
# b. TOTAL_RECHARGE_REV_LAST_MONTH - 100,200,300,500
# c. TOTAL_RECHARGE_REV_LAST_2_WEEKs - 50,60,70,80
# d. TOTAL_RECHARGE_REV_LAST_WEEK - 25,30,35,40
# if any query related to
